# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukeshyadav07/ITPR_Lab-Work/blob/main/Calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculation3.py
from numericcalculation import addNumbers
m=10
n=20
print("sum of",m,"and",n,"is:",addNumbers(m,n))

# %%
#calculateon.py
import numericcalculation
m=10
n=20
print("sum of",m,"and",n,"is:",numericcalculation addNumbers(m,n))
print("product of",m,"and",n,"is:",numericcalculation calculate product(m,n))

# %%
#calculateon2.py
from numericcalculation import *
m=10
n=20
print("sum of",m,"and",n,"is:",numericcalculation addNumbers(m,n))
